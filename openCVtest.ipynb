# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load Image and Do Edge Stuff

# %%
img = cv2.imread('./images/test.jpg',0)
edges = cv2.Canny(img, 100,200)

# %% [markdown]
# ### Display Images

# %%
print(img)
# Out:
# [[ 89  71  96 ..., 178 178 178]
#  [100  75  89 ..., 178 178 178]
#  [113  79  79 ..., 179 179 179]
#  ...,
#  [104  87  68 ...,  92  78  92]
#  [ 75  61  58 ...,  85  77  95]
#  [ 76  69  76 ...,  82  79 101]]

# %%
plt.subplot(121),
plt.imshow(img, cmap = 'gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(edges, cmap = 'gray')
plt.title('Edge')
plt.xticks([])
plt.yticks([])

plt.show()
