# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load Image, Create and Show Edges

# %%
#img = cv2.imread('../../data/train/images/0b73b427d1.png')
img = cv2.imread('../../data/train/images/0a1742c740.png')
edges = cv2.Canny(img,150,160,apertureSize=3)

plt.figure(0)
plt.imshow(img)

plt.figure(1)
plt.imshow(edges, cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e1d53a3f980e> in <module>()
#       4
#       5 plt.figure(0)
# ----> 6 plt.imshow(img)
#       7
#       8 plt.figure(1)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %% [markdown]
# ### Experimenting

# %%
#img = cv2.imread('../../data/train/images/0b73b427d1.png')
img2 = cv2.imread('../../data/train/images/0a1742c740.png')
edges2 = cv2.Canny(img2,150,160,apertureSize=3, L2gradient=True)

plt.figure(0)
plt.imshow(img2)

plt.figure(1)
plt.imshow(edges2, cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-41f55708bd95> in <module>()
#       4
#       5 plt.figure(0)
# ----> 6 plt.imshow(img2)
#       7
#       8 plt.figure(1)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %% [markdown]
# ### Hough Line Transform

# %%
lines = cv2.HoughLinesP(edges, 1, np.pi/180, 20)

for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 1)

plt.figure(3)
plt.imshow(img)

# %% [markdown]
# ### Experimenting

# %%
img = cv2.imread('../../data/train/images/0a1742c740.png')
# lines_ = cv2.HoughLinesP(edges2, 1, np.pi/180, 20)
lines_ = cv2.HoughLinesP(edges2, 1, np.pi/180, 20, minLineLength = 5, maxLineGap = 15)

for line in lines_:
    x1, y1, x2, y2 = line[0]
    cv2.line(img2, (x1, y1), (x2, y2), (0, 255, 0), 1)

plt.figure(4)
plt.imshow(img2)
