# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load Image and Do Edge Stuff

# %%
#img = cv2.imread('./images/test.jpg',0)
img = cv2.imread('../../data/train/images/0b73b427d1.png')
edges = cv2.Canny(img,400,410,apertureSize=3)

# %% [markdown]
# ### Display Images

# %%
print(img)
# Out:
# [[[ 50  50  50]
#   [ 63  63  63]
#   [ 81  81  81]
#   ...
#   [100 100 100]
#   [ 89  89  89]
#   [ 93  93  93]]
#
#  [[ 60  60  60]
#   [ 73  73  73]
#   [ 84  84  84]
#   ...
#   [ 99  99  99]
#   [ 91  91  91]
#   [ 96  96  96]]
#
#  [[ 78  78  78]
#   [ 88  88  88]
#   [ 89  89  89]
#   ...
#   [100 100 100]
#   [ 95  95  95]
#   [100 100 100]]
#
#  ...
#
#  [[116 116 116]
#   [113 113 113]
#   [115 115 115]
#   ...
#   [115 115 115]
#   [119 119 119]
#   [118 118 118]]
#
#  [[120 120 120]
#   [118 118 118]
#   [120 120 120]
#   ...
#   [109 109 109]
#   [115 115 115]
#   [115 115 115]]
#
#  [[126 126 126]
#   [124 124 124]
#   [124 124 124]
#   ...
#   [102 102 102]
#   [110 110 110]
#   [111 111 111]]]

# %%
plt.subplot(121),
plt.imshow(img, cmap = 'gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(edges, cmap = 'gray')
plt.title('Edge')
plt.xticks([])
plt.yticks([])

plt.show()

# %%
edges2 = cv2.Canny(edges,600,610,apertureSize=5)

# %%
plt.subplot(121),
plt.imshow(edges, cmap = 'gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(edges2, cmap = 'gray')
plt.title('Edge')
plt.xticks([])
plt.yticks([])

plt.show()
